# %% [markdown]
# ## Download and prepare the dataset

# %%
import numpy as np
import shutil
from zipfile import ZipFile
import matplotlib.pyplot as plt
import os
from PIL import Image
import cv2
import glob
import random
from sklearn.model_selection import train_test_split

# %%
! gdown --id 1KWnX3eMPJrzhsegi0LmyGUbUV5pqKw_R
# !apt-get install -y unzip
# !unzip ss_dataset.zip
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1KWnX3eMPJrzhsegi0LmyGUbUV5pqKw_R
# To: /content/ss_dataset.zip
# 100% 5.59G/5.59G [00:34<00:00, 161MB/s]
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# unzip is already the newest version (6.0-25ubuntu1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 15 not upgraded.
# Archive:  ss_dataset.zip
#    creating: ss_dataset/
#    creating: ss_dataset/3/
#   inflating: ss_dataset/3/210.bmp
#   inflating: ss_dataset/3/65_label.bmp
#   inflating: ss_dataset/3/495.bmp
#   inflating: ss_dataset/3/266.bmp
#   inflating: ss_dataset/3/423_label.bmp
#   inflating: ss_dataset/3/518_label.bmp
#   inflating: ss_dataset/3/540_label.bmp
#   inflating: ss_dataset/3/423.bmp
#   inflating: ss_dataset/3/221.bmp
#   inflating: ss_dataset/3/391.bmp
#   inflating: ss_dataset/3/309_label.bmp
#   inflating: ss_dataset/3/70.bmp
#   inflating: ss_dataset/3/231.bmp
#   inflating: ss_dataset/3/90_label.bmp
#   inflating: ss_dataset/3/10.bmp
#   inflating: ss_dataset/3/554_label.bmp
#   inflating: ss_dataset/3/215.bmp
#   inflating: ss_dataset/3/425_label.bmp
#   inflating: ss_dataset/3/18_label.bmp
#   inflating: ss_dataset/3/435.bmp
#   inflating: ss_dataset/3/491_label.bmp
#   inflating: ss_dataset/3/468.bmp
#   inflating: ss_dataset/3/85_label.bmp
#   inflating: ss_dataset/3/347.bmp
#   inflating: ss_dataset/3/398_label.bmp
#   inflating: ss_dataset/3/582.bmp
#   inflating: ss_dataset/3/560_label.bmp
#   inflating: ss_dataset/3/495_label.bmp
#   inflating: ss_dataset/3/35.bmp
#   inflating: ss_dataset/3/263.bmp
#   inflating: ss_dataset/3/393_label.bmp
#   inflating: ss_dataset/3/407.bmp
#   inflating: ss_dataset/3/165_label.bmp
#   inflating: ss_dataset/3/535_label.bmp
#   inflating: ss_dataset/3/571.bmp
#   inflating: ss_dataset/3/417_label.bmp
#   inflating: ss_dataset/3/31_label.bmp
#   inflating: ss_dataset/3/39_label.bmp
#   inflating: ss_dataset/3/22_label.bmp
#   inflating: ss_dataset/3/316_label.bmp
#   inflating: ss_dataset/3/514.bmp
#   inflating: ss_dataset/3/444_label.bmp
#   inflating: ss_dataset/3/88.bmp
#   inflating: ss_dataset/3/546_label.bmp
#   inflating: ss_dataset/3/237_label.bmp
#   inflating: ss_dataset/3/223.bmp
#   inflating: ss_dataset/3/301_label.bmp
#   inflating: ss_dataset/3/163.bmp
#   inflating: ss_dataset/3/177.bmp
#   inflating: ss_dataset/3/236.bmp
#   inflating: ss_dataset/3/443.bmp
#   inflating: ss_dataset/3/532.bmp
#   inflating: ss_dataset/3/43_label.bmp
#   inflating: ss_dataset/3/239_label.bmp
#   inflating: ss_dataset/3/550_label.bmp
#   inflating: ss_dataset/3/513_label.bmp
#   inflating: ss_dataset/3/517_label.bmp
#   inflating: ss_dataset/3/516.bmp
#   inflating: ss_dataset/3/269.bmp
#   inflating: ss_dataset/3/617.bmp
#   inflating: ss_dataset/3/473.bmp
#   inflating: ss_dataset/3/87.bmp
#   inflating: ss_dataset/3/26.bmp
#   inflating: ss_dataset/3/507.bmp
#   inflating: ss_dataset/3/504_label.bmp
#   inflating: ss_dataset/3/117.bmp
#   inflating: ss_dataset/3/411.bmp
#   inflating: ss_dataset/3/582_label.bmp
#   inflating: ss_dataset/3/100.bmp
#   inflating: ss_dataset/3/357_label.bmp
#   inflating: ss_dataset/3/204.bmp
#   inflating: ss_dataset/3/213_label.bmp
#   inflating: ss_dataset/3/536.bmp
#   inflating: ss_dataset/3/509.bmp
#   inflating: ss_dataset/3/312_label.bmp
#   inflating: ss_dataset/3/612.bmp
#   inflating: ss_dataset/3/590_label.bmp
#   inflating: ss_dataset/3/340_label.bmp
#   inflating: ss_dataset/3/267.bmp
#   inflating: ss_dataset/3/306.bmp
#   inflating: ss_dataset/3/222.bmp
# ...
#   inflating: ss_dataset/2/115_label.bmp
#   inflating: ss_dataset/2/39.bmp
#   inflating: ss_dataset/2/105.bmp
#   inflating: ss_dataset/2/32.bmp
#   inflating: ss_dataset/2/139_label.bmp
#   inflating: ss_dataset/2/148_label.bmp
#   inflating: ss_dataset/2/14_label.bmp
#   inflating: ss_dataset/2/68.bmp
#   inflating: ss_dataset/2/160_label.bmp
#   inflating: ss_dataset/2/228.bmp
#   inflating: ss_dataset/2/202.bmp
#   inflating: ss_dataset/2/229.bmp
#   inflating: ss_dataset/2/172_label.bmp
#   inflating: ss_dataset/2/7.bmp
#   inflating: ss_dataset/2/171_label.bmp
#   inflating: ss_dataset/2/141.bmp
#   inflating: ss_dataset/2/109.bmp
#   inflating: ss_dataset/2/153.bmp
#   inflating: ss_dataset/2/22.bmp
#   inflating: ss_dataset/2/46.bmp
#   inflating: ss_dataset/2/65.bmp
#   inflating: ss_dataset/2/23_label.bmp
#   inflating: ss_dataset/2/171.bmp
#   inflating: ss_dataset/2/212_label.bmp
#   inflating: ss_dataset/2/202_label.bmp
#   inflating: ss_dataset/2/55_label.bmp
#   inflating: ss_dataset/2/185_label.bmp
#   inflating: ss_dataset/2/177_label.bmp
#   inflating: ss_dataset/2/71_label.bmp
#   inflating: ss_dataset/2/205.bmp
#   inflating: ss_dataset/2/179.bmp
#   inflating: ss_dataset/2/15_label.bmp
#   inflating: ss_dataset/2/1_label.bmp
#   inflating: ss_dataset/2/167.bmp
#   inflating: ss_dataset/2/64_label.bmp
#   inflating: ss_dataset/2/197_label.bmp
#   inflating: ss_dataset/2/151.bmp
#   inflating: ss_dataset/2/44_label.bmp
#   inflating: ss_dataset/2/203_label.bmp
#   inflating: ss_dataset/2/157_label.bmp
#   inflating: ss_dataset/2/95_label.bmp
#   inflating: ss_dataset/2/122.bmp
#   inflating: ss_dataset/2/108.bmp
#   inflating: ss_dataset/2/42.bmp
#   inflating: ss_dataset/2/176.bmp
#   inflating: ss_dataset/2/43.bmp
#   inflating: ss_dataset/2/93.bmp
#   inflating: ss_dataset/2/157.bmp
#   inflating: ss_dataset/2/144_label.bmp
#   inflating: ss_dataset/2/162.bmp
#   inflating: ss_dataset/2/148.bmp
#   inflating: ss_dataset/2/101_label.bmp
#   inflating: ss_dataset/2/161_label.bmp
#   inflating: ss_dataset/2/54_label.bmp
#   inflating: ss_dataset/2/178.bmp
#   inflating: ss_dataset/2/214.bmp
#   inflating: ss_dataset/2/224.bmp
#   inflating: ss_dataset/2/149.bmp
#   inflating: ss_dataset/2/74_label.bmp
#   inflating: ss_dataset/2/231_label.bmp
#   inflating: ss_dataset/2/38.bmp
#   inflating: ss_dataset/2/29.bmp
#   inflating: ss_dataset/2/235.bmp
#   inflating: ss_dataset/2/117_label.bmp
#   inflating: ss_dataset/2/141_label.bmp
#   inflating: ss_dataset/2/62.bmp
#   inflating: ss_dataset/2/173.bmp
#   inflating: ss_dataset/2/130_label.bmp
#   inflating: ss_dataset/2/125_label.bmp
#   inflating: ss_dataset/2/72.bmp
#   inflating: ss_dataset/2/28_label.bmp
#   inflating: ss_dataset/2/25.bmp
#   inflating: ss_dataset/2/27.bmp
#   inflating: ss_dataset/2/156_label.bmp
#   inflating: ss_dataset/2/185.bmp
#   inflating: ss_dataset/2/90.bmp
#   inflating: ss_dataset/2/9.bmp
#   inflating: ss_dataset/2/81_label.bmp
#   inflating: ss_dataset/2/88_label.bmp
#   inflating: ss_dataset/2/164.bmp
#   inflating: ss_dataset/2/44.bmp
#   inflating: ss_dataset/2/159.bmp
#   inflating: ss_dataset/2/78_label.bmp
#   inflating: ss_dataset/2/19_label.bmp
#   inflating: ss_dataset/2/187_label.bmp
#   inflating: ss_dataset/2/120_label.bmp
#   inflating: ss_dataset/2/199_label.bmp
#   inflating: ss_dataset/2/35_label.bmp
#   inflating: ss_dataset/2/89.bmp
#   inflating: ss_dataset/2/32_label.bmp
#   inflating: ss_dataset/2/230.bmp
#   inflating: ss_dataset/2/181_label.bmp
#   inflating: ss_dataset/2/225.bmp
#   inflating: ss_dataset/2/232.bmp
#   inflating: ss_dataset/2/1.bmp
#   inflating: ss_dataset/2/218.bmp
#   inflating: ss_dataset/2/24.bmp
#   inflating: ss_dataset/2/26_label.bmp
#   inflating: ss_dataset/2/6.bmp
#   inflating: ss_dataset/2/226.bmp
#   inflating: ss_dataset/2/69.bmp
#   inflating: ss_dataset/2/75.bmp
#   inflating: ss_dataset/2/49.bmp
#   inflating: ss_dataset/2/121.bmp
#   inflating: ss_dataset/2/206_label.bmp
#   inflating: ss_dataset/2/174.bmp
#   inflating: ss_dataset/2/125.bmp
#   inflating: ss_dataset/2/96_label.bmp
#   inflating: ss_dataset/2/142.bmp
#   inflating: ss_dataset/2/143_label.bmp
#   inflating: ss_dataset/2/63.bmp
#   inflating: ss_dataset/2/120.bmp
#   inflating: ss_dataset/2/30.bmp
#   inflating: ss_dataset/2/119.bmp
#   inflating: ss_dataset/2/149_label.bmp
#   inflating: ss_dataset/2/163_label.bmp
#   inflating: ss_dataset/2/86_label.bmp
#   inflating: ss_dataset/2/226_label.bmp
#   inflating: ss_dataset/2/46_label.bmp
#   inflating: ss_dataset/2/50_label.bmp
#   inflating: ss_dataset/2/17_label.bmp
#   inflating: ss_dataset/2/137_label.bmp
#   inflating: ss_dataset/2/41_label.bmp
#   inflating: ss_dataset/2/145.bmp
#   inflating: ss_dataset/2/210_label.bmp
#   inflating: ss_dataset/2/84_label.bmp
#   inflating: ss_dataset/2/102.bmp
#   inflating: ss_dataset/2/34.bmp
#   inflating: ss_dataset/2/188.bmp
#   inflating: ss_dataset/2/196.bmp
#   inflating: ss_dataset/2/94_label.bmp
#   inflating: ss_dataset/2/217.bmp
#   inflating: ss_dataset/2/207_label.bmp
#   inflating: ss_dataset/2/123.bmp
#   inflating: ss_dataset/2/81.bmp
#   inflating: ss_dataset/2/198.bmp
#   inflating: ss_dataset/2/87.bmp
#   inflating: ss_dataset/2/26.bmp
#   inflating: ss_dataset/2/117.bmp
#   inflating: ss_dataset/2/100.bmp
#   inflating: ss_dataset/2/204.bmp
#   inflating: ss_dataset/2/213_label.bmp
#   inflating: ss_dataset/2/222.bmp
#   inflating: ss_dataset/2/200_label.bmp
#   inflating: ss_dataset/2/29_label.bmp
#   inflating: ss_dataset/2/119_label.bmp
#   inflating: ss_dataset/2/103.bmp
#   inflating: ss_dataset/2/66.bmp
#   inflating: ss_dataset/2/208.bmp
#   inflating: ss_dataset/2/84.bmp
#   inflating: ss_dataset/2/112.bmp
#   inflating: ss_dataset/2/37_label.bmp
#   inflating: ss_dataset/2/142_label.bmp
#   inflating: ss_dataset/2/194.bmp
#   inflating: ss_dataset/2/192_label.bmp
#   inflating: ss_dataset/2/129.bmp
#   inflating: ss_dataset/2/54.bmp
#   inflating: ss_dataset/2/170_label.bmp
#   inflating: ss_dataset/2/74.bmp
#   inflating: ss_dataset/2/204_label.bmp
#   inflating: ss_dataset/2/53_label.bmp
#   inflating: ss_dataset/2/16_label.bmp
#   inflating: ss_dataset/2/147_label.bmp
#   inflating: ss_dataset/2/13.bmp
#   inflating: ss_dataset/2/19.bmp
#    creating: ss_dataset/5/
#   inflating: ss_dataset/5/65_label.bmp
#   inflating: ss_dataset/5/70.bmp
#   inflating: ss_dataset/5/90_label.bmp
#   inflating: ss_dataset/5/10.bmp
#   inflating: ss_dataset/5/18_label.bmp
#   inflating: ss_dataset/5/85_label.bmp
#   inflating: ss_dataset/5/35.bmp
#   inflating: ss_dataset/5/31_label.bmp
#   inflating: ss_dataset/5/39_label.bmp
#   inflating: ss_dataset/5/22_label.bmp
#   inflating: ss_dataset/5/88.bmp
#   inflating: ss_dataset/5/43_label.bmp
#   inflating: ss_dataset/5/58.bmp
#   inflating: ss_dataset/5/115.bmp
#   inflating: ss_dataset/5/100_label.bmp
#   inflating: ss_dataset/5/3.bmp
#   inflating: ss_dataset/5/30_label.bmp
#   inflating: ss_dataset/5/38_label.bmp
#   inflating: ss_dataset/5/18.bmp
#   inflating: ss_dataset/5/80_label.bmp
#   inflating: ss_dataset/5/56_label.bmp
#   inflating: ss_dataset/5/27_label.bmp
#   inflating: ss_dataset/5/83.bmp
#   inflating: ss_dataset/5/91_label.bmp
#   inflating: ss_dataset/5/105_label.bmp
#   inflating: ss_dataset/5/48.bmp
#   inflating: ss_dataset/5/106.bmp
#   inflating: ss_dataset/5/57_label.bmp
#   inflating: ss_dataset/5/40_label.bmp
#   inflating: ss_dataset/5/96.bmp
#   inflating: ss_dataset/5/45_label.bmp
#   inflating: ss_dataset/5/82_label.bmp
#   inflating: ss_dataset/5/3_label.bmp
#   inflating: ss_dataset/5/12.bmp
#   inflating: ss_dataset/5/116.bmp
#   inflating: ss_dataset/5/2_label.bmp
#   inflating: ss_dataset/5/36.bmp
#   inflating: ss_dataset/5/118_label.bmp
#   inflating: ss_dataset/5/49_label.bmp
#   inflating: ss_dataset/5/92_label.bmp
#   inflating: ss_dataset/5/13_label.bmp
#   inflating: ss_dataset/5/34_label.bmp
#   inflating: ss_dataset/5/10_label.bmp
#   inflating: ss_dataset/5/98_label.bmp
#   inflating: ss_dataset/5/73.bmp
#   inflating: ss_dataset/5/51_label.bmp
#   inflating: ss_dataset/5/83_label.bmp
#   inflating: ss_dataset/5/107_label.bmp
#   inflating: ss_dataset/5/73_label.bmp
#   inflating: ss_dataset/5/76.bmp
#   inflating: ss_dataset/5/60_label.bmp
#   inflating: ss_dataset/5/97_label.bmp
#   inflating: ss_dataset/5/15.bmp
#   inflating: ss_dataset/5/79_label.bmp
#   inflating: ss_dataset/5/8.bmp
#   inflating: ss_dataset/5/110_label.bmp
#   inflating: ss_dataset/5/24_label.bmp
#   inflating: ss_dataset/5/58_label.bmp
#   inflating: ss_dataset/5/67_label.bmp
#   inflating: ss_dataset/5/4_label.bmp
#   inflating: ss_dataset/5/64.bmp
#   inflating: ss_dataset/5/114_label.bmp
#   inflating: ss_dataset/5/103_label.bmp
#   inflating: ss_dataset/5/33_label.bmp
#   inflating: ss_dataset/5/99_label.bmp
#   inflating: ss_dataset/5/101.bmp
#   inflating: ss_dataset/5/104.bmp
#   inflating: ss_dataset/5/114.bmp
#   inflating: ss_dataset/5/51.bmp
#   inflating: ss_dataset/5/47_label.bmp
#   inflating: ss_dataset/5/4.bmp
#   inflating: ss_dataset/5/61_label.bmp
#   inflating: ss_dataset/5/69_label.bmp
#   inflating: ss_dataset/5/56.bmp
#   inflating: ss_dataset/5/45.bmp
#   inflating: ss_dataset/5/17.bmp
#   inflating: ss_dataset/5/111_label.bmp
#   inflating: ss_dataset/5/14.bmp
#   inflating: ss_dataset/5/113_label.bmp
#   inflating: ss_dataset/5/104_label.bmp
#   inflating: ss_dataset/5/8_label.bmp
#   inflating: ss_dataset/5/113.bmp
#   inflating: ss_dataset/5/33.bmp
#   inflating: ss_dataset/5/109_label.bmp
#   inflating: ss_dataset/5/110.bmp
#   inflating: ss_dataset/5/111.bmp
#   inflating: ss_dataset/5/57.bmp
#   inflating: ss_dataset/5/23.bmp
#   inflating: ss_dataset/5/25_label.bmp
#   inflating: ss_dataset/5/62_label.bmp
#   inflating: ss_dataset/5/20_label.bmp
#   inflating: ss_dataset/5/93_label.bmp
#   inflating: ss_dataset/5/48_label.bmp
#   inflating: ss_dataset/5/55.bmp
#   inflating: ss_dataset/5/102_label.bmp
#   inflating: ss_dataset/5/11.bmp
#   inflating: ss_dataset/5/20.bmp
#   inflating: ss_dataset/5/0_label.bmp
#   inflating: ss_dataset/5/82.bmp
#   inflating: ss_dataset/5/59.bmp
#   inflating: ss_dataset/5/95.bmp
#   inflating: ss_dataset/5/91.bmp
#   inflating: ss_dataset/5/99.bmp
#   inflating: ss_dataset/5/94.bmp
#   inflating: ss_dataset/5/78.bmp
#   inflating: ss_dataset/5/87_label.bmp
#   inflating: ss_dataset/5/70_label.bmp
#   inflating: ss_dataset/5/108_label.bmp
#   inflating: ss_dataset/5/7_label.bmp
#   inflating: ss_dataset/5/92.bmp
#   inflating: ss_dataset/5/0.bmp
#   inflating: ss_dataset/5/71.bmp
#   inflating: ss_dataset/5/118.bmp
#   inflating: ss_dataset/5/77.bmp
#   inflating: ss_dataset/5/21_label.bmp
#   inflating: ss_dataset/5/50.bmp
#   inflating: ss_dataset/5/5.bmp
#   inflating: ss_dataset/5/59_label.bmp
#   inflating: ss_dataset/5/75_label.bmp
#   inflating: ss_dataset/5/2.bmp
#   inflating: ss_dataset/5/12_label.bmp
#   inflating: ss_dataset/5/97.bmp
#   inflating: ss_dataset/5/16.bmp
#   inflating: ss_dataset/5/77_label.bmp
#   inflating: ss_dataset/5/80.bmp
#   inflating: ss_dataset/5/41.bmp
#   inflating: ss_dataset/5/6_label.bmp
#   inflating: ss_dataset/5/9_label.bmp
#   inflating: ss_dataset/5/40.bmp
#   inflating: ss_dataset/5/107.bmp
#   inflating: ss_dataset/5/85.bmp
#   inflating: ss_dataset/5/61.bmp
#   inflating: ss_dataset/5/5_label.bmp
#   inflating: ss_dataset/5/68_label.bmp
#   inflating: ss_dataset/5/67.bmp
#   inflating: ss_dataset/5/89_label.bmp
#   inflating: ss_dataset/5/21.bmp
#   inflating: ss_dataset/5/116_label.bmp
#   inflating: ss_dataset/5/60.bmp
#   inflating: ss_dataset/5/98.bmp
#   inflating: ss_dataset/5/72_label.bmp
#   inflating: ss_dataset/5/31.bmp
#   inflating: ss_dataset/5/86.bmp
#   inflating: ss_dataset/5/63_label.bmp
#   inflating: ss_dataset/5/79.bmp
#   inflating: ss_dataset/5/66_label.bmp
#   inflating: ss_dataset/5/11_label.bmp
#   inflating: ss_dataset/5/47.bmp
#   inflating: ss_dataset/5/53.bmp
#   inflating: ss_dataset/5/42_label.bmp
#   inflating: ss_dataset/5/28.bmp
#   inflating: ss_dataset/5/52_label.bmp
#   inflating: ss_dataset/5/37.bmp
#   inflating: ss_dataset/5/36_label.bmp
#   inflating: ss_dataset/5/106_label.bmp
#   inflating: ss_dataset/5/76_label.bmp
#   inflating: ss_dataset/5/52.bmp
#   inflating: ss_dataset/5/112_label.bmp
#   inflating: ss_dataset/5/115_label.bmp
#   inflating: ss_dataset/5/39.bmp
#   inflating: ss_dataset/5/105.bmp
#   inflating: ss_dataset/5/32.bmp
#   inflating: ss_dataset/5/14_label.bmp
#   inflating: ss_dataset/5/68.bmp
#   inflating: ss_dataset/5/7.bmp
#   inflating: ss_dataset/5/109.bmp
#   inflating: ss_dataset/5/22.bmp
#   inflating: ss_dataset/5/46.bmp
#   inflating: ss_dataset/5/65.bmp
#   inflating: ss_dataset/5/23_label.bmp
#   inflating: ss_dataset/5/55_label.bmp
#   inflating: ss_dataset/5/71_label.bmp
#   inflating: ss_dataset/5/15_label.bmp
#   inflating: ss_dataset/5/1_label.bmp
#   inflating: ss_dataset/5/64_label.bmp
#   inflating: ss_dataset/5/44_label.bmp
#   inflating: ss_dataset/5/95_label.bmp
#   inflating: ss_dataset/5/108.bmp
#   inflating: ss_dataset/5/42.bmp
#   inflating: ss_dataset/5/43.bmp
#   inflating: ss_dataset/5/93.bmp
#   inflating: ss_dataset/5/101_label.bmp
#   inflating: ss_dataset/5/54_label.bmp
#   inflating: ss_dataset/5/74_label.bmp
#   inflating: ss_dataset/5/38.bmp
#   inflating: ss_dataset/5/29.bmp
#   inflating: ss_dataset/5/117_label.bmp
#   inflating: ss_dataset/5/62.bmp
#   inflating: ss_dataset/5/72.bmp
#   inflating: ss_dataset/5/28_label.bmp
#   inflating: ss_dataset/5/25.bmp
#   inflating: ss_dataset/5/27.bmp
#   inflating: ss_dataset/5/90.bmp
#   inflating: ss_dataset/5/9.bmp
#   inflating: ss_dataset/5/81_label.bmp
#   inflating: ss_dataset/5/88_label.bmp
#   inflating: ss_dataset/5/44.bmp
#   inflating: ss_dataset/5/78_label.bmp
#   inflating: ss_dataset/5/19_label.bmp
#   inflating: ss_dataset/5/35_label.bmp
#   inflating: ss_dataset/5/89.bmp
#   inflating: ss_dataset/5/32_label.bmp
#   inflating: ss_dataset/5/1.bmp
#   inflating: ss_dataset/5/24.bmp
#   inflating: ss_dataset/5/26_label.bmp
#   inflating: ss_dataset/5/6.bmp
#   inflating: ss_dataset/5/69.bmp
#   inflating: ss_dataset/5/75.bmp
#   inflating: ss_dataset/5/49.bmp
#   inflating: ss_dataset/5/96_label.bmp
#   inflating: ss_dataset/5/63.bmp
#   inflating: ss_dataset/5/30.bmp
#   inflating: ss_dataset/5/86_label.bmp
#   inflating: ss_dataset/5/46_label.bmp
#   inflating: ss_dataset/5/50_label.bmp
#   inflating: ss_dataset/5/17_label.bmp
#   inflating: ss_dataset/5/41_label.bmp
#   inflating: ss_dataset/5/84_label.bmp
#   inflating: ss_dataset/5/102.bmp
#   inflating: ss_dataset/5/34.bmp
#   inflating: ss_dataset/5/94_label.bmp
#   inflating: ss_dataset/5/81.bmp
#   inflating: ss_dataset/5/87.bmp
#   inflating: ss_dataset/5/26.bmp
#   inflating: ss_dataset/5/117.bmp
#   inflating: ss_dataset/5/100.bmp
#   inflating: ss_dataset/5/29_label.bmp
#   inflating: ss_dataset/5/103.bmp
#   inflating: ss_dataset/5/66.bmp
#   inflating: ss_dataset/5/84.bmp
#   inflating: ss_dataset/5/112.bmp
#   inflating: ss_dataset/5/37_label.bmp
#   inflating: ss_dataset/5/54.bmp
#   inflating: ss_dataset/5/74.bmp
#   inflating: ss_dataset/5/53_label.bmp
#   inflating: ss_dataset/5/16_label.bmp
#   inflating: ss_dataset/5/13.bmp
#   inflating: ss_dataset/5/19.bmp

# %%
root_dir = '/content/ss_dataset'

data_dir = os.path.join(root_dir)

image_root = '/content/train'
label_root = '/content/train_masks'
if not os.path.isdir(image_root):
    os.mkdir(image_root)
if not os.path.isdir(label_root):
    os.mkdir(label_root)

images = list()
labels = list()

'''
Iterate the whole dataset and aggregate the files as png image file in train and train_masks
directories
'''

################################################
############## YOUR CODES GO HERE ##############

# have file paths in a list
for j in os.listdir(data_dir):
    for i in os.listdir(os.path.join(data_dir, j)):
        if i.endswith('.bmp'):
            if '_label' in i:
                labels.append(os.path.join(os.path.join(data_dir, j), i))
            else:
                images.append(os.path.join(os.path.join(data_dir, j), i))

for path in images:
    #read the image
    image = Image.open(path)
    #resize the image
    resized = image.resize((256, 256))
    #save the image as png
    new_name = os.path.basename(path)
    new_name = os.path.splitext(new_name)[0]
    resized.save(os.path.join(image_root, f"{new_name}.png"), 'PNG')

# Process labeled images too
for path in labels:
    #read the image
    image = Image.open(path)
    #resize the image
    resized = image.resize((256, 256))
    #save the image as png
    new_name = os.path.basename(path)
    new_name = os.path.splitext(new_name)[0]
    resized.save(os.path.join(label_root, f"{new_name}.png"), 'PNG')

################################################

# %%
print("Train set:  ", len(os.listdir("/content/train")))
print("Train masks:", len(os.listdir("/content/train_masks")))
# Out:
# Train set:   859
# Train masks: 859

# %%
'''
Create yolo-based labels for each image.
Consider the routine describes in the question.
Don't forget to split the dataset to train and val
Hint:
  https://www.geeksforgeeks.org/find-and-draw-contours-using-opencv-python/
  https://docs.opencv.org/4.x/da/d0c/tutorial_bounding_rects_circles.html
'''

################################################
############## YOUR CODES GO HERE ##############

def yolo_based_label(contours , image):

    #define the labels as said in the pdf
    with open(label_path, 'w') as f:
        for contour in contours:
            x, y, w, h = cv2.boundingRect(contour)
            #get center and w and h normalized and then write it in the file
            y_normalized = (y + h / 2) / image.shape[0]
            x_normalized = (x + w / 2) / image.shape[1]
            w_normalized = w / image.shape[1]
            h_normalized = h / image.shape[0]
            f.write(f"{0} {x_normalized:.6f} {y_normalized:.6f} {w_normalized:.6f} {h_normalized:.6f}" + "\n")

for image_file in os.listdir(image_root):
    image_path = os.path.join(image_root, image_file)
    label_path = os.path.join(image_root, os.path.splitext(image_file)[0] + '.txt')
    # read images and convert to gray and then binary
    image = cv2.imread(image_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    #find the contours
    contours, _ = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

    yolo_based_label(contours,image)

    # save images in train folder
    img_name = os.path.splitext(os.path.basename(image_path))[0] + '.png'
    img_path = os.path.join('train', img_name)
    cv2.imwrite(img_path, image)

print(len(os.listdir(label_root)))
################################################
# Out:
# 859

# %%
# !ls train/*.png | wc -l
# Out:
# 859

# %%
# !ls train/*.txt | wc -l
# Out:
# 859

# %%
def plot_bbox_on_img(rect, img):
    '''
    draw the rects around objects and show the result
    '''
    ################################################
    ############## YOUR CODES GO HERE ##############
    imgfile = cv2.imread(img)
    for r in rect:
        x, y, w, h = map(int,r)
        cv2.rectangle(imgfile, (x, y), (x + w, y + h), (0, 255, 0), 2)
    ################################################
    plt.imshow(imgfile)
    plt.show()

base_path = 'content/train'
txtsPath = 'content/train'

txts = glob.glob(os.path.join(txtsPath, '*.txt'))

for txt in txts[:10]:
    plot_bbox_on_img(txt, os.path.join(base_path, '{}.png'.format(txt.split('/')[-1].split('.')[0])))

# %% [markdown]
# ## Train the model

# %%
# !git clone https://github.com/WongKinYiu/yolov7.git

# %%
#### Clone the codes from repo: https://github.com/WongKinYiu/yolov7.git
#### Read the readme file

################################################
############## YOUR CODES GO HERE ##############

# !pip install -qr /content/yolov7/requirements.txt

################################################
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 55.0 MB/s eta 0:00:00

# %%
data_path = '/content/'
image_path = '/content/train'
label_path = '/content/train_masks'

train_file = os.path.join(data_path, 'train.txt')
val_file = os.path.join(data_path, 'val.txt')

class_names = ['0', '1']
image_files = [f for f in os.listdir(image_path) if f.endswith('.jpg') or f.endswith('.png')]

# make train and validation dataset
train, validation = train_test_split(image_files, test_size=0.2, random_state=42)

# make the train file
with open(train_file, 'w') as f:
    for name in train:
        image_path = os.path.join(image_path, name)
        label_path = os.path.join(image_path, name.replace('.jpg', '.txt').replace('.png', '.txt'))
        if os.path.isfile(label_path):
            f.write(f"{image_path}\n")
            f.write(f"{label_path}\n")


# make the val file
with open(val_file, 'w') as f:
    for name in validation:
        image_path = os.path.join(image_path, name)
        label_path = os.path.join(image_path, name.replace('.jpg', '.txt').replace('.png', '.txt'))
        if os.path.isfile(label_path):
            f.write(f"{image_path}\n")
            f.write(f"{label_path}\n")



# make the YAML file
yaml = os.path.join(data_path, 'customdata.yaml')

with open(yaml, 'w') as f:
    f.write("# Dataset\n\n")
    f.write(f"train: {train_file}\n")
    f.write(f"val: {val_file}\n")
    f.write("\n")
    f.write("# Number of classes\n")
    f.write(f"nc: {len(class_names)}\n")
    f.write("\n")
    f.write("# Class names\n")
    f.write("names: " + str(class_names))

# %%
# !python train_aux.py --workers 8 --device 0 --batch-size 16 --data /content/customdata.yaml --img 256 256 --cfg cfg/training/yolov7-w6.yaml --weights '' --name yolov7-w6 --hyp data/hyp.scratch.p6.yaml
# !python train.py --workers 8 --device 0 --batch-size 32 --data /content/customdata.yaml --img 256 256 --cfg cfg/training/yolov7.yaml --weights '' --name yolov7 --hyp data/hyp.scratch.p5.yaml

# %% [markdown]
# ## Inference the trained model

# %%
### Show the results


################################################
############## YOUR CODES GO HERE ##############

################################################
